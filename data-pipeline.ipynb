# %%
import os
import torch
import librosa
import torchaudio
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from IPython.display import Audio

# %%
# data_dir = '/Users/rudyhendrawan/miniforge3/datasets/Bio-Akustik-Gajah'
data_dir = '/Users/rudyh/Documents/Python/datasets/Bio-Akustik-Gajah/'

metadata = pd.read_csv(os.path.join(data_dir, 'metadata.csv'))
metadata.shape
# Out:
# (2019, 13)

# %%
metadata.tail()
# Out:
#      selection           view channel         start_time           end_time  \
# 2014         4  Spectrogram 1       1     21.231.400.986     23.433.828.474
# 2015         5  Spectrogram 1       1    681.857.289.707    685.733.562.086
# 2016         6  Spectrogram 1       1  1.526.725.179.890  1.532.980.073.956
# 2017         7  Spectrogram 1       1  1.556.254.289.547  1.559.690.076.429
# 2018         8  Spectrogram 1       1  1.908.304.676.065  1.912.445.239.743
#
#      LowFreq HighFreq         sound_category sound_type confidence notes  \
# 2014  24.130   63.996  elephant_vocalization      growl          1   NaN
# 2015  14.688   53.505  elephant_vocalization      growl          1   NaN
# 2016  23.081   36.719  elephant_vocalization      growl          1   NaN
# 2017  17.804   31.899  elephant_vocalization      growl          1   NaN
# 2018  20.030   31.899  elephant_vocalization      growl          1   NaN
#
#        name                                     filename
# 2014  fanny  ELOC2_1654520897346_2022-06-06_23-08-17.wav
# 2015  fanny  ELOC2_1654520897346_2022-06-06_23-08-17.wav
# 2016  fanny  ELOC2_1654520897346_2022-06-06_23-08-17.wav
# 2017  fanny  ELOC2_1654520897346_2022-06-06_23-08-17.wav
# 2018  fanny  ELOC2_1654520897346_2022-06-06_23-08-17.wav
